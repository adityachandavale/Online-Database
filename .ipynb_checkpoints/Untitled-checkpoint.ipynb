# %%
import pymongo as pm

client = pm.MongoClient("mongodb+srv://aditya:aditya123@database.yyjna.mongodb.net/Database?retryWrites=true&w=majority")
db = client['Database']
col = db['contact']

col.insert_one({"_id":1})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in _get_socket(self, all_credentials)
#    1393                     with self.lock:
# -> 1394                         sock_info = self.sockets.popleft()
#    1395                 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13520/2777284237.py in <module>
#       5 col = db['contact']
#       6
# ----> 7 col.insert_one({"_id":1})
#       8
#       9 for i in col.find():
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     703         write_concern = self._write_concern_for(session)
#     704         return InsertOneResult(
# --> 705             self._insert(document,
#     706                          write_concern=write_concern,
#     707                          bypass_doc_val=bypass_document_validation,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     618         """Internal insert helper."""
#     619         if isinstance(docs, abc.Mapping):
# --> 620             return self._insert_one(
#     621                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     622                 bypass_doc_val, session)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     607             _check_write_command_response(result)
#     608
# --> 609         self.__database.client._retryable_write(
#     610             acknowledged, _insert_command, session)
#     611
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1550         """Internal retryable write helper."""
#    1551         with self._tmp_session(session) as s:
# -> 1552             return self._retry_with_session(retryable, func, s, None)
#    1553
#    1554     def _handle_getlasterror(self, address, error_msg):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1436         retryable = (retryable and self.retry_writes
#    1437                      and session and not session.in_transaction)
# -> 1438         return self._retry_internal(retryable, func, session, bulk)
#    1439
#    1440     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1460                     session is not None and
#    1461                     server.description.retryable_writes_supported)
# -> 1462                 with self._get_socket(server, session) as sock_info:
#    1463                     max_wire_version = sock_info.max_wire_version
#    1464                     if retryable and not supports_session:
#
# c:\program files\python39\lib\contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\mongo_client.py in _get_socket(self, server, session)
#    1306                 yield session._pinned_connection
#    1307                 return
# -> 1308             with server.get_socket(
#    1309                     self.__all_credentials, handler=err_handler) as sock_info:
#    1310                 # Pin this session to the selected server or connection.
#
# c:\program files\python39\lib\contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in get_socket(self, all_credentials, handler)
#    1329             listeners.publish_connection_check_out_started(self.address)
#    1330
# -> 1331         sock_info = self._get_socket(all_credentials)
#    1332         if self.enabled_for_cmap:
#    1333             listeners.publish_connection_checked_out(
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in _get_socket(self, all_credentials)
#    1395                 except IndexError:
#    1396                     # Can raise ConnectionFailure or CertificateError.
# -> 1397                     sock_info = self.connect(all_credentials)
#    1398                 else:
#    1399                     if self._perished(sock_info):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in connect(self, all_credentials)
#    1295                 self.is_writable = sock_info.is_writable
#    1296
# -> 1297             sock_info.check_auth(all_credentials)
#    1298         except BaseException:
#    1299             sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in check_auth(self, all_credentials)
#     818
#     819             for credentials in cached - authset:
# --> 820                 self.authenticate(credentials)
#     821
#     822         # CMAP spec says to publish the ready event only after authenticating
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in authenticate(self, credentials)
#     835           - `credentials`: A MongoCredential.
#     836         """
# --> 837         auth.authenticate(credentials, self)
#     838         self.authset.add(credentials)
#     839         # negotiated_mechanisms are no longer needed.
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\auth.py in authenticate(credentials, sock_info)
#     670     mechanism = credentials.mechanism
#     671     auth_func = _AUTH_MAP.get(mechanism)
# --> 672     auth_func(credentials, sock_info)
#     673
#     674
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\auth.py in _authenticate_default(credentials, sock_info)
#     588             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     589         else:
# --> 590             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     591     elif sock_info.max_wire_version >= 3:
#     592         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     293         nonce, first_bare, cmd = _authenticate_scram_start(
#     294             credentials, mechanism)
# --> 295         res = sock_info.command(source, cmd)
#     296
#     297     server_first = res['payload']
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\pool.py in command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708             self._raise_if_not_writable(unacknowledged)
#     709         try:
# --> 710             return command(self, dbname, spec, secondary_ok,
#     711                            self.is_mongos, read_preference, codec_options,
#     712                            session, client, check, allowable_errors,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\network.py in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156                 client._process_response(response_doc, session)
#     157             if check:
# --> 158                 helpers._check_command_response(
#     159                     response_doc, sock_info.max_wire_version, allowable_errors,
#     160                     parse_write_concern_error=parse_write_concern_error)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     165         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     166
# --> 167     raise OperationFailure(errmsg, code, response, max_wire_version)
#     168
#     169
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}
